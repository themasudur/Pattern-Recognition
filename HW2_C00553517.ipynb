# %% [markdown]
# <a href="https://colab.research.google.com/github/themasudur/Pattern-Recognition/blob/main/HW2_C00553517.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

X1, y1 = make_moons(n_samples=250, noise=0.20, random_state=51)
X2, y2 = make_moons(n_samples=250, noise=0.35, random_state=51)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.scatter(X1[:, 0], X1[:, 1], c=y1)
plt.title('make_moons (noise=0.20)')
plt.xlim([-2.5, 2.5])
plt.ylim([-2.5, 2.5])

plt.subplot(1, 2, 2)
plt.scatter(X2[:, 0], X2[:, 1], c=y2)
plt.title('make_moons (noise=0.35)')
plt.xlim([-2.5, 2.5])
plt.ylim([-2.5, 2.5])
plt.tight_layout()
plt.show()

# %%
# 2
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.3, random_state=51)

# Create a Decision Tree classifier
dt_classifier = DecisionTreeClassifier(random_state=509)

# Train the classifier
dt_classifier.fit(X_train, y_train)

# Make predictions
# on the test set y_pred = dt_classifier.predict(X_test)
y_pred = dt_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Base DT Accuracy: {accuracy:.2f}")
# Out:
# Base DT Accuracy: 0.92

# %%
for k in [1, 3, 4]:
  dt_clf = DecisionTreeClassifier(max_depth=k, random_state=509)
  dt_clf.fit(X_train, y_train)
  y_pred = dt_clf.predict(X_test)
  accuracy = accuracy_score(y_test, y_pred)
  print(f"DT Accuracy (max_depth={k}): {accuracy:.2f}")
# Out:
# DT Accuracy (max_depth=1): 0.79
# DT Accuracy (max_depth=3): 0.89
# DT Accuracy (max_depth=4): 0.83

# %%
# 3
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X2, y2, test_size=0.3, random_state=51)

# Create a Decision Tree classifier
dt_classifier_depth = DecisionTreeClassifier(max_depth=2, random_state=509)

# Train the classifier
dt_classifier.fit(X_train, y_train)

# Make predictions
# on the test set y_pred = dt_classifier.predict(X_test)
y_pred = dt_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Base DT Accuracy: {accuracy:.2f}")
# Out:
# Base DT Accuracy: 0.80

# %%
for k in [1, 3, 4]:
  dt_clf = DecisionTreeClassifier(max_depth=k, random_state=509)
  dt_clf.fit(X_train, y_train)
  y_pred = dt_clf.predict(X_test)
  accuracy = accuracy_score(y_test, y_pred)
  print(f"DT Accuracy (max_depth={k}): {accuracy:.2f}")
# Out:
# DT Accuracy (max_depth=1): 0.75
# DT Accuracy (max_depth=3): 0.84
# DT Accuracy (max_depth=4): 0.87
